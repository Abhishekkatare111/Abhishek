# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekkatare111/Abhishek/blob/main/Practical_no2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Abhishek vinod katare")
print("Roll no.  135")
print("Introduction to python programming")
print("practical no. 2")
# Out:
# Abhishek vinod katare
# Roll no.  135
# Introduction to python programming
# practical no. 2

# %%
first_string =20
type(first_string)
# Out:
# int

# %%
first_string= "Hello world"
first_string='Hello world'
print(  )

# %%
first_string[0]
first_string[1]
# Out:
# 'e'

# %%
print(first_string)
first_string[1:4]
first_string[1:11:2]
# Out:
# Hello world
# 'el ol'

# %%
string1='Hello'
string2='world'
string3=string1+string2
print(string3)
# Out:
# Helloworld

# %%
string1='Hello'
string2='world'
string3=string1+' '+string2
print(string3)
# Out:
# Hello world

# %%
stra="hello"
strb="20"
print(stra+' '+strb)
# Out:
# hello 20

# %%
first_name= 'Abhishek'
Last_name='katare'
age=19
print("My first name is",first_name,"last name is",Last_name," and age is",age);
# Out:
# My first name is Abhishek last name is katare  and age is 19

# %%
str="Hello world!!!"
print(str[5:10])
print(str[ :10])
print(str[5: ])
print(str[ : ])
print(str[-8:-3])
print(str[5: :2])
print(str[ : : -1])
print(str[-10 : -1])
# Out:
#  worl
# Hello worl
#  world!!!
# Hello world!!!
# world
#  ol!!
# !!!dlrow olleH
# o world!!

# %%
str="hello world"
print("Original string", str)
str1=len(str)
print("Length of string=",str1)
# Out:
# Original string hello world
# Length of string= 11

# %%
print("Original string= ",str)
str1=str.title()
print("Title case=",str1)
str1=str.upper()
print("upper case=",str1)
str1=str.lower()
print("lower case=",str1)
# Out:
# Original string=  hello world
# Title case= Hello World
# upper case= HELLO WORLD
# lower case= hello world

# %%
str1="Hello world!! Hello Hello"
str1.count('Hello')
# Out:
# 3

# %%
str1.count('Hello',12,25)
# Out:
# 2

# %%
str1.find( "Hell",10,20)
# Out:
# 14

# %%
str1.find('Hello',15,25)
# Out:
# 20

# %%
str1.find("Hee")
# Out:
# -1

# %%
str1.index("Hello")
# Out:
# 0

# %%
str1.index("He")
# Out:
# 0

# %%
str1.lower()
# Out:
# 'hello world!! hello hello'

# %%
str1="hello"
str1.islower()
# Out:
# True

# %%
str1='hello 1234'
str. islower()
# Out:
# True

# %%
str="Hello world!"
str.endswith("world!")
# Out:
# True

# %%
str1.endswith("!")
# Out:
# False

# %%
str1.endswith("end")
# Out:
# False

# %%
str1.startswith("He")
# Out:
# False

# %%
str.startswith("Hee")
# Out:
# False

# %%
str1="Hello world"
str1. isalnum()
# Out:
# False

# %%
str1="Hello world 2"
str1.isalnum()
# Out:
# False

# %%
str1="Hello world!!"
str1.isalnum()
# Out:
# False

# %%
str='1234'
str1.isalnum()
# Out:
# False

# %%
str1="Hello world!"
str1.isupper()
# Out:
# False

# %%
str="HELLO"
str1.isupper()
# Out:
# False

# %%
str1="HE123"
str1.isupper()
# Out:
# True

# %%
str1="hi"
str1.isupper()
# Out:
# False

# %%
str='India is a Great Country'
str.partition('is')
# Out:
# ('India ', 'is', ' a Great Country')

# %%
str.partition('are')
# Out:
# ('India is a Great Country', '', '')

# %%
str.split()
# Out:
# ['India', 'is', 'a', 'Great', 'Country']

# %%
str.split('a')
# Out:
# ['Indi', ' is ', ' Gre', 't Country']

# %%
str="Hello world"
str2='_'
str2.join(str)
# Out:
# 'H_e_l_l_o_ _w_o_r_l_d'

# %%
str="  Hello world  "
str.lstrip()
# Out:
# 'Hello world  '

# %%
str.rstrip()
# Out:
# '  Hello world'

# %%
str.strip()
# Out:
# 'Hello world'

# %%
str1="Hello world"
str1.replace("o","*")
# Out:
# 'Hell* w*rld'

# %%
print(str1)
# Out:
# Hello world

# %%
str1.replace("world","country")
# Out:
# 'Hello country'
